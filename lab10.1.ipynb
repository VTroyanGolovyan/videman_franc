# %%
from matplotlib import pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd
sns.set(style="darkgrid", font_scale=1.4)

# %% [markdown]
# Троян-Головян Владслав,Б05-912 группа

# %% [markdown]
# ### **`Лабараторная работа 10.1`**

# %% [markdown]
#  **Электронный парамагнитный резонанс**

# %% [markdown]
# ![E7012CAC-62B4-404B-BAB3-8488A9B05E7C.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# **Рис. Блок-схема установки для наблюдения ЭПР. Измерение постоянного и переменного токов через катушки $N_2$ производится с помощью вольтметра $PB7-22A$ и сопротивления $R = 10$ Ом, включенного в цепь катушек**

# %% [markdown]
# **Ход работы**

# %% [markdown]
# Настроили установку. Параметры катушек:
#
# *   Основная катушка: $N_{осн} = 6700$, $d_{осн} = 0.25 \pm 0.01 м.
#
# *   Модулирующая катушка: $N_{мод} = 5000$, $d_мод = 0.30 \pm 0.01 мм$.
#
# *   Пробная катушка $N_{проб} = 45$,$d_{проб} = 15.2 \pm 0.1 мм$.

# %% [markdown]
# Сначала мы настроили высокочастотный генератор на частоту колебательго контура.Для удобства наблюдения на осциллографе модулировали сигнал низкими частотами (около 10 кГц,глубина модуляции составляла 20%). Частоту на генераторе подобрали таким образом, чтобы амплитуда синуса на осциллографе была максимальной, этого получилось достичь при $\omega_{рез}=164 \pm 4$ МГц.

# %% [markdown]
# Далее мы занялись наблюдением сигнала резонансного поглощения. Подключили основные катушки к источнику постоянного тока,а на модуляционные катушки через ЛАТР подали переменное напряжение 50В. Напряжение на основных катушках увеличивали до тех пор пока не начали наблюдать характерные для резонансного поглощения осциллограммы. Нужное напряжение составило $V_0=130 \pm 1$ B.

# %% [markdown]
# ![5E061518-2A7C-486B-89E7-F53FCDFA1142.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# **Осциллограмма резонансного поглощения ДФПГ.**

# %% [markdown]
# Провели измерения для определения ширины линии парамагнитного резонанса и g-фактора, подстроив осцилограмму фазовращателем. По экрану осциллографа мы определили максимальную высоту резонансного пика и его ширину на половине высоты. $A_{полн} = (5.0 \pm 0.4)$ дел, $A_{\frac{1}{2}} = 1 \pm 0.4 дел.$

# %% [markdown]
# Для того чтобы определить магнитное поле, которое создают основные катушки,мы поменяли в них напряжение с постоянного тока на переменный (подавая напряжение с ЛАТРА) и выставили напряжение которое близко к $V_0$. Поднеся пробную катушку,подсоединенную к вольтметру вплотную к образцу,измерили ЭДС индукции, наводимую катушками:$ɛ = 14.6 \pm 0.2 $ мВ.

# %% [markdown]
# Чтобы определить поле модуляционных катушек,поступили аналогично и получили $ɛ_{мод} = 1.22 \pm 0.02 мВ$

# %% [markdown]
# ![891E4615-E74B-4AFE-99F9-5023A076D10E.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# **Без подстройки фазовращателем**

# %% [markdown]
# ![D42D59BE-442D-4363-923D-92547E4D00F1.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# **С подстройкой фазовращателем.**

# %% [markdown]
# ### **Обработка результатов**

# %% [markdown]
# **1.Измерение $g$-фактора для электрона**

# %% [markdown]
# По формуле 3 имеем $B_0=5.7 \pm 0.2$ мТл
#
# Воспользуемся измеренной $ω_{рез}$ а также соотношением 2, имеем $g=2.0 \pm 0.1$

# %% [markdown]
# 2. Ширина линии ЭПР

# %% [markdown]
# Поформуле 3 $B_{мод}=0.47 \pm 0.01$ мТл.
#
# А ширина линии определяется как:
# $ΔB=\frac{А{1/2}}{A_{полн}}B_{мод} = 0.09 \pm 0.03 $ мТл

# %% [markdown]
# **Вывод**

# %% [markdown]
# Нами был исследован парамагнитный резонанс в радикале дифинилпикрилгидразила (ДФПГ). Наблюдалась резонансная кривая поглощения образцом электромагнитного поля,была выполнена оценка ширины этой линии $ΔB = 0.09 \pm 0.03$ мТл

# %% [markdown]
# Также мы измерили $g-фактор$ свободного электрона, где в роли свободного электрона выступал радикальный электрон ДФПГ. Ожидалось что оно будет близко к значению 2 для полностью свободного электрона. Было получено значение $g=2.0 \pm 0.1$. Для сравнения в теории оно равно 2.0036 тоесть наш резултьтат близок к теории.

# %% [markdown]
# Погрешость результата составила 5.6% и она связана с приборными погрешностями.Остальные эффекты, связанные с теоретическими приближениями должны играть малую роль.
